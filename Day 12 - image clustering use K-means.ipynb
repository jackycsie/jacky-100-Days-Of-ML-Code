# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage
from sklearn import cluster
image = ndimage.imread("./dataset/cat.jpg")
plt.figure(figsize = (15,8))
plt.imshow(image)
# Out:
# /home/letitgo/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.

# %%
image.shape
# Out:
# (960, 540, 3)

# %%
x, y, z = image.shape
image_2d = image.reshape(x*y, z)
image_2d.shape
# Out:
# (518400, 3)

# %%
kmeans_cluster = cluster.KMeans(n_clusters=9)
kmeans_cluster.fit(image_2d)
cluster_centers = kmeans_cluster.cluster_centers_
cluster_centers
# Out:
# array([[ 90.57735827,  82.06926302,  67.84097376],
#        [195.99740752, 202.85242796, 209.28690132],
#        [139.96344799, 133.21046853, 120.84389036],
#        [248.6739172 , 251.40005528, 242.79943016],
#        [ 26.14841668,  23.88857829,  23.37706923],
#        [167.53480713, 162.90962758, 156.90968013],
#        [232.26940432, 198.23869917, 151.17349745],
#        [119.10215158, 106.1337064 ,  87.55272737],
#        [ 67.98044839,  58.584453  ,  47.38733925]])

# %%
cluster_labels = kmeans_cluster.labels_
cluster_labels
# Out:
# array([3, 3, 3, ..., 7, 7, 7], dtype=int32)

# %%
plt.figure(figsize = (15,8))
plt.imshow((cluster_centers[cluster_labels]*255).reshape(x, y, z).astype(np.uint8))
